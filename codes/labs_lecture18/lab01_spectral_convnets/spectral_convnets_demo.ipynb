# %% [markdown]
# # Lab 01 : Spectral ConvNets - demo

# %% [markdown]
# Implementation of spectral graph ConvNets<br>
# Convolutional Neural Networks on Graphs with Fast Localized Spectral Filtering<br>
# M Defferrard, X Bresson, P Vandergheynst<br>
# Advances in Neural Information Processing Systems, 3844-3852, 2016<br>
# ArXiv preprint: [arXiv:1606.09375](https://arxiv.org/pdf/1606.09375.pdf) <br>

# %%
import torch
from torch.autograd import Variable
import torch.nn.functional as F
import torch.nn as nn
import pdb #pdb.set_trace()
import collections
import time
import numpy as np

import sys
sys.path.insert(0, 'lib/')
# %load_ext autoreload
# %autoreload 2

# Remove warnings
import warnings
warnings.filterwarnings("ignore")

import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

if torch.cuda.is_available():
    print('cuda available')
    dtypeFloat = torch.cuda.FloatTensor
    dtypeLong = torch.cuda.LongTensor
    torch.cuda.manual_seed(1)
else:
    print('cuda not available')
    dtypeFloat = torch.FloatTensor
    dtypeLong = torch.LongTensor
    torch.manual_seed(1)
# Out:
# cuda available

# %% [markdown]
# # MNIST

# %%
from utils import check_mnist_dataset_exists
data_path=check_mnist_dataset_exists()

train_data=torch.load(data_path+'mnist/train_data.pt')
train_label=torch.load(data_path+'mnist/train_label.pt')
test_data=torch.load(data_path+'mnist/test_data.pt')
test_label=torch.load(data_path+'mnist/test_label.pt')

print(train_data.size())
print(test_data.size())

train_data = train_data.numpy().reshape([60000,784])
test_data = test_data.numpy().reshape([10000,784])
print(train_data.shape)
print(test_data.shape)
# Out:
# torch.Size([60000, 28, 28])
# torch.Size([10000, 28, 28])
# (60000, 784)
# (10000, 784)

# %% [markdown]
# # Graph

# %%
from lib.grid_graph import grid_graph
from lib.coarsening import coarsen
from lib.coarsening import lmax_L
from lib.coarsening import perm_data
from lib.coarsening import rescale_L

# Construct graph
t_start = time.time()
grid_side = 28
number_edges = 8
metric = 'euclidean'
A = grid_graph(grid_side,number_edges,metric) # create graph of Euclidean grid

# Compute coarsened graphs
coarsening_levels = 4
L, perm = coarsen(A, coarsening_levels)

# Compute max eigenvalue of graph Laplacians
lmax = []
for i in range(coarsening_levels):
    lmax.append(lmax_L(L[i]))
print('lmax: ' + str([lmax[i] for i in range(coarsening_levels)]))

# Reindex nodes to satisfy a binary tree structure
train_data = perm_data(train_data, perm)
test_data = perm_data(test_data, perm)

print(train_data.shape)
print(test_data.shape)

print('Execution time: {:.2f}s'.format(time.time() - t_start))
del perm
# Out:
# nb edges:  6396
# Heavy Edge Matching coarsening with Xavier version
# Layer 0: M_0 = |V| = 912 nodes (128 added), |E| = 3198 edges
# Layer 1: M_1 = |V| = 456 nodes (53 added), |E| = 1592 edges
# Layer 2: M_2 = |V| = 228 nodes (19 added), |E| = 769 edges
# Layer 3: M_3 = |V| = 114 nodes (5 added), |E| = 366 edges
# Layer 4: M_4 = |V| = 57 nodes (0 added), |E| = 183 edges
# lmax: [1.3857541, 1.3441446, 1.219872, 0.99999976]
# (60000, 912)
# (10000, 912)
# Execution time: 1.72s

# %% [markdown]
# # Graph ConvNet LeNet5
# ### Layers: CL32-MP4-CL64-MP4-FC512-FC10

# %%
# class definitions

class my_sparse_mm(torch.autograd.Function):
    """
    Implementation of a new autograd function for sparse variables, 
    called "my_sparse_mm", by subclassing torch.autograd.Function 
    and implementing the forward and backward passes.
    """
    
    def forward(self, W, x):  # W is SPARSE
        self.save_for_backward(W, x)
        y = torch.mm(W, x)
        return y
    
    def backward(self, grad_output):
        W, x = self.saved_tensors 
        grad_input = grad_output.clone()
        grad_input_dL_dW = torch.mm(grad_input, x.t()) 
        grad_input_dL_dx = torch.mm(W.t(), grad_input )
        return grad_input_dL_dW, grad_input_dL_dx
    
    
class Graph_ConvNet_LeNet5(nn.Module):
    
    def __init__(self, net_parameters):
        
        print('Graph ConvNet: LeNet5')
        
        super(Graph_ConvNet_LeNet5, self).__init__()
        
        # parameters
        D, CL1_F, CL1_K, CL2_F, CL2_K, FC1_F, FC2_F = net_parameters
        FC1Fin = CL2_F*(D//16)
        
        # graph CL1
        self.cl1 = nn.Linear(CL1_K, CL1_F) 
        Fin = CL1_K; Fout = CL1_F;
        scale = np.sqrt( 2.0/ (Fin+Fout) )
        self.cl1.weight.data.uniform_(-scale, scale)
        self.cl1.bias.data.fill_(0.0)
        self.CL1_K = CL1_K; self.CL1_F = CL1_F; 
        
        # graph CL2
        self.cl2 = nn.Linear(CL2_K*CL1_F, CL2_F) 
        Fin = CL2_K*CL1_F; Fout = CL2_F;
        scale = np.sqrt( 2.0/ (Fin+Fout) )
        self.cl2.weight.data.uniform_(-scale, scale)
        self.cl2.bias.data.fill_(0.0)
        self.CL2_K = CL2_K; self.CL2_F = CL2_F; 

        # FC1
        self.fc1 = nn.Linear(FC1Fin, FC1_F) 
        Fin = FC1Fin; Fout = FC1_F;
        scale = np.sqrt( 2.0/ (Fin+Fout) )
        self.fc1.weight.data.uniform_(-scale, scale)
        self.fc1.bias.data.fill_(0.0)
        self.FC1Fin = FC1Fin
        
        # FC2
        self.fc2 = nn.Linear(FC1_F, FC2_F)
        Fin = FC1_F; Fout = FC2_F;
        scale = np.sqrt( 2.0/ (Fin+Fout) )
        self.fc2.weight.data.uniform_(-scale, scale)
        self.fc2.bias.data.fill_(0.0)

        # nb of parameters
        nb_param = CL1_K* CL1_F + CL1_F          # CL1
        nb_param += CL2_K* CL1_F* CL2_F + CL2_F  # CL2
        nb_param += FC1Fin* FC1_F + FC1_F        # FC1
        nb_param += FC1_F* FC2_F + FC2_F         # FC2
        print('nb of parameters=',nb_param,'\n')
        
        
    def init_weights(self, W, Fin, Fout):

        scale = np.sqrt( 2.0/ (Fin+Fout) )
        W.uniform_(-scale, scale)

        return W
        
        
    def graph_conv_cheby(self, x, cl, L, lmax, Fout, K):

        # parameters
        # B = batch size
        # V = nb vertices
        # Fin = nb input features
        # Fout = nb output features
        # K = Chebyshev order & support size
        B, V, Fin = x.size(); B, V, Fin = int(B), int(V), int(Fin) 

        # rescale Laplacian
        lmax = lmax_L(L)
        L = rescale_L(L, lmax) 
        
        # convert scipy sparse matric L to pytorch
        L = L.tocoo()
        indices = np.column_stack((L.row, L.col)).T 
        indices = indices.astype(np.int64)
        indices = torch.from_numpy(indices)
        indices = indices.type(torch.LongTensor)
        L_data = L.data.astype(np.float32)
        L_data = torch.from_numpy(L_data) 
        L_data = L_data.type(torch.FloatTensor)
        L = torch.sparse.FloatTensor(indices, L_data, torch.Size(L.shape))
        L = Variable( L , requires_grad=False)
        if torch.cuda.is_available():
            L = L.cuda()
        
        # transform to Chebyshev basis
        x0 = x.permute(1,2,0).contiguous()  # V x Fin x B
        x0 = x0.view([V, Fin*B])            # V x Fin*B
        x = x0.unsqueeze(0)                 # 1 x V x Fin*B
        
        def concat(x, x_):
            x_ = x_.unsqueeze(0)            # 1 x V x Fin*B
            return torch.cat((x, x_), 0)    # K x V x Fin*B  
             
        if K > 1: 
            x1 = my_sparse_mm()(L,x0)              # V x Fin*B
            x = torch.cat((x, x1.unsqueeze(0)),0)  # 2 x V x Fin*B
        for k in range(2, K):
            x2 = 2 * my_sparse_mm()(L,x1) - x0  
            x = torch.cat((x, x2.unsqueeze(0)),0)  # M x Fin*B
            x0, x1 = x1, x2  
        
        x = x.view([K, V, Fin, B])           # K x V x Fin x B     
        x = x.permute(3,1,2,0).contiguous()  # B x V x Fin x K       
        x = x.view([B*V, Fin*K])             # B*V x Fin*K
        
        # Compose linearly Fin features to get Fout features
        x = cl(x)                            # B*V x Fout  
        x = x.view([B, V, Fout])             # B x V x Fout
        
        return x
        
        
    # Max pooling of size p. Must be a power of 2.
    def graph_max_pool(self, x, p): 
        if p > 1: 
            x = x.permute(0,2,1).contiguous()  # x = B x F x V
            x = nn.MaxPool1d(p)(x)             # B x F x V/p          
            x = x.permute(0,2,1).contiguous()  # x = B x V/p x F
            return x  
        else:
            return x    
        
        
    def forward(self, x, d, L, lmax):
        
        # graph CL1
        x = x.unsqueeze(2) # B x V x Fin=1  
        x = self.graph_conv_cheby(x, self.cl1, L[0], lmax[0], self.CL1_F, self.CL1_K)
        x = F.relu(x)
        x = self.graph_max_pool(x, 4)
        
        # graph CL2
        x = self.graph_conv_cheby(x, self.cl2, L[2], lmax[2], self.CL2_F, self.CL2_K)
        x = F.relu(x)
        x = self.graph_max_pool(x, 4)
        
        # FC1
        x = x.view(-1, self.FC1Fin)
        x = self.fc1(x)
        x = F.relu(x)
        x  = nn.Dropout(d)(x)
        
        # FC2
        x = self.fc2(x)
            
        return x
        
        
    def loss(self, y, y_target, l2_regularization):
    
        loss = nn.CrossEntropyLoss()(y,y_target)

        l2_loss = 0.0
        for param in self.parameters():
            data = param* param
            l2_loss += data.sum()
           
        loss += 0.5* l2_regularization* l2_loss
            
        return loss
    
    
    def update(self, lr):
                
        update = torch.optim.SGD( self.parameters(), lr=lr, momentum=0.9 )
        
        return update
        
        
    def update_learning_rate(self, optimizer, lr):
   
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr

        return optimizer

    
    def evaluation(self, y_predicted, test_l):
    
        _, class_predicted = torch.max(y_predicted.data, 1)
        return 100.0* (class_predicted == test_l).sum().float()/ y_predicted.size(0)

# %%
# Delete existing network if exists
try:
    del net
    print('Delete existing network\n')
except NameError:
    print('No existing network to delete\n')



# network parameters
D = train_data.shape[1]
CL1_F = 32
CL1_K = 25
CL2_F = 64
CL2_K = 25
FC1_F = 512
FC2_F = 10
net_parameters = [D, CL1_F, CL1_K, CL2_F, CL2_K, FC1_F, FC2_F]


# instantiate the object net of the class 
net = Graph_ConvNet_LeNet5(net_parameters)
if torch.cuda.is_available():
    net.cuda()
print(net)


# Weights
L_net = list(net.parameters())


# learning parameters
learning_rate = 0.05
dropout_value = 0.5
l2_regularization = 5e-4 
batch_size = 100
num_epochs = 20
train_size = train_data.shape[0]
nb_iter = int(num_epochs * train_size) // batch_size
print('num_epochs=',num_epochs,', train_size=',train_size,', nb_iter=',nb_iter)


# Optimizer
global_lr = learning_rate
global_step = 0
decay = 0.95
decay_steps = train_size
lr = learning_rate
optimizer = net.update(lr) 


# loop over epochs
indices = collections.deque()
for epoch in range(num_epochs):  # loop over the dataset multiple times

    # reshuffle 
    indices.extend(np.random.permutation(train_size)) # rand permutation
    
    # reset time
    t_start = time.time()
    
    # extract batches
    running_loss = 0.0
    running_accuray = 0
    running_total = 0
    while len(indices) >= batch_size:
        
        # extract batches
        batch_idx = [indices.popleft() for i in range(batch_size)]
        train_x, train_y = train_data[batch_idx,:], train_label[batch_idx]
        train_x = Variable( torch.FloatTensor(train_x).type(dtypeFloat) , requires_grad=False)
        train_y = Variable( torch.LongTensor(train_y).type(dtypeLong) , requires_grad=False) 
            
        # Forward 
        y = net.forward(train_x, dropout_value, L, lmax)
        loss = net.loss(y,train_y,l2_regularization) 
        loss_train = loss.data.item()
        
        # Accuracy
        acc_train = net.evaluation(y,train_y.data)
        
        # backward
        loss.backward()
        
        # Update 
        global_step += batch_size # to update learning rate
        optimizer.step()
        optimizer.zero_grad()
        
        # loss, accuracy
        running_loss += loss_train
        running_accuray += acc_train
        running_total += 1
        
        # print        
        if not running_total%100: # print every x mini-batches
            print('epoch= %d, i= %4d, loss(batch)= %.4f, accuray(batch)= %.2f' % (epoch+1, running_total, loss_train, acc_train))
          
       
    # print 
    t_stop = time.time() - t_start
    print('epoch= %d, loss(train)= %.3f, accuracy(train)= %.3f, time= %.3f, lr= %.5f' % 
          (epoch+1, running_loss/running_total, running_accuray/running_total, t_stop, lr))
 

    # update learning rate 
    lr = global_lr * pow( decay , float(global_step// decay_steps) )
    optimizer = net.update_learning_rate(optimizer, lr)
    
    
    # Test set
    running_accuray_test = 0
    running_total_test = 0
    indices_test = collections.deque()
    indices_test.extend(range(test_data.shape[0]))
    t_start_test = time.time()
    while len(indices_test) >= batch_size:
        batch_idx_test = [indices_test.popleft() for i in range(batch_size)]
        test_x, test_y = test_data[batch_idx_test,:], test_label[batch_idx_test]
        test_x = Variable( torch.FloatTensor(test_x).type(dtypeFloat) , requires_grad=False)
        test_y = Variable( torch.LongTensor(test_y).type(dtypeLong) , requires_grad=False) 
        y = net.forward(test_x, 0.0, L, lmax)        
        acc_test = net.evaluation(y,test_y.data)
        running_accuray_test += acc_test
        running_total_test += 1
    t_stop_test = time.time() - t_start_test
    print('  accuracy(test) = %.3f %%, time= %.3f' % (running_accuray_test / running_total_test, t_stop_test))
# Out:
# Delete existing network
#
# Graph ConvNet: LeNet5
# nb of parameters= 1925514
#
# Graph_ConvNet_LeNet5(
#   (cl1): Linear(in_features=25, out_features=32, bias=True)
#   (cl2): Linear(in_features=800, out_features=64, bias=True)
#   (fc1): Linear(in_features=3648, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=10, bias=True)
# )
# num_epochs= 20 , train_size= 60000 , nb_iter= 12000
# epoch= 1, i=  100, loss(batch)= 0.3377, accuray(batch)= 93.00
# epoch= 1, i=  200, loss(batch)= 0.2061, accuray(batch)= 95.00
# epoch= 1, i=  300, loss(batch)= 0.2036, accuray(batch)= 98.00
# epoch= 1, i=  400, loss(batch)= 0.3240, accuray(batch)= 92.00
# epoch= 1, i=  500, loss(batch)= 0.1783, accuray(batch)= 98.00
# epoch= 1, i=  600, loss(batch)= 0.2232, accuray(batch)= 96.00
# epoch= 1, loss(train)= 0.377, accuracy(train)= 91.325, time= 77.352, lr= 0.05000
#   accuracy(test) = 97.900 %, time= 7.073
# epoch= 2, i=  100, loss(batch)= 0.1588, accuray(batch)= 99.00
# epoch= 2, i=  200, loss(batch)= 0.1779, accuray(batch)= 98.00
# epoch= 2, i=  300, loss(batch)= 0.1191, accuray(batch)= 100.00
# epoch= 2, i=  400, loss(batch)= 0.1925, accuray(batch)= 98.00
# epoch= 2, i=  500, loss(batch)= 0.1785, accuray(batch)= 98.00
# epoch= 2, i=  600, loss(batch)= 0.2397, accuray(batch)= 95.00
# epoch= 2, loss(train)= 0.181, accuracy(train)= 97.657, time= 84.211, lr= 0.04750
#   accuracy(test) = 98.550 %, time= 6.671
# epoch= 3, i=  100, loss(batch)= 0.1343, accuray(batch)= 98.00
# epoch= 3, i=  200, loss(batch)= 0.1641, accuray(batch)= 97.00
# epoch= 3, i=  300, loss(batch)= 0.2254, accuray(batch)= 98.00
# epoch= 3, i=  400, loss(batch)= 0.1157, accuray(batch)= 100.00
# epoch= 3, i=  500, loss(batch)= 0.1237, accuray(batch)= 99.00
# epoch= 3, i=  600, loss(batch)= 0.1257, accuray(batch)= 99.00
# epoch= 3, loss(train)= 0.149, accuracy(train)= 98.293, time= 76.593, lr= 0.04512
#   accuracy(test) = 98.840 %, time= 6.272
# epoch= 4, i=  100, loss(batch)= 0.1018, accuray(batch)= 100.00
# epoch= 4, i=  200, loss(batch)= 0.1212, accuray(batch)= 99.00
# epoch= 4, i=  300, loss(batch)= 0.1568, accuray(batch)= 97.00
# epoch= 4, i=  400, loss(batch)= 0.1015, accuray(batch)= 100.00
# epoch= 4, i=  500, loss(batch)= 0.1175, accuray(batch)= 98.00
# epoch= 4, i=  600, loss(batch)= 0.1584, accuray(batch)= 97.00
# epoch= 4, loss(train)= 0.130, accuracy(train)= 98.665, time= 77.482, lr= 0.04287
#   accuracy(test) = 98.740 %, time= 6.273
# epoch= 5, i=  100, loss(batch)= 0.1034, accuray(batch)= 99.00
# epoch= 5, i=  200, loss(batch)= 0.1496, accuray(batch)= 99.00
# epoch= 5, i=  300, loss(batch)= 0.1394, accuray(batch)= 99.00
# epoch= 5, i=  400, loss(batch)= 0.1139, accuray(batch)= 98.00
# epoch= 5, i=  500, loss(batch)= 0.0918, accuray(batch)= 100.00
# epoch= 5, i=  600, loss(batch)= 0.0965, accuray(batch)= 100.00
# epoch= 5, loss(train)= 0.117, accuracy(train)= 98.790, time= 77.444, lr= 0.04073
#   accuracy(test) = 98.960 %, time= 6.867
# epoch= 6, i=  100, loss(batch)= 0.1031, accuray(batch)= 99.00
# epoch= 6, i=  200, loss(batch)= 0.1439, accuray(batch)= 98.00
# epoch= 6, i=  300, loss(batch)= 0.0798, accuray(batch)= 100.00
# epoch= 6, i=  400, loss(batch)= 0.2061, accuray(batch)= 94.00
# epoch= 6, i=  500, loss(batch)= 0.0814, accuray(batch)= 99.00
# epoch= 6, i=  600, loss(batch)= 0.0810, accuray(batch)= 100.00
# epoch= 6, loss(train)= 0.108, accuracy(train)= 98.970, time= 76.594, lr= 0.03869
#   accuracy(test) = 98.940 %, time= 6.291
# epoch= 7, i=  100, loss(batch)= 0.0923, accuray(batch)= 99.00
# epoch= 7, i=  200, loss(batch)= 0.0857, accuray(batch)= 100.00
# epoch= 7, i=  300, loss(batch)= 0.1046, accuray(batch)= 98.00
# epoch= 7, i=  400, loss(batch)= 0.0884, accuray(batch)= 99.00
# epoch= 7, i=  500, loss(batch)= 0.0796, accuray(batch)= 100.00
# epoch= 7, i=  600, loss(batch)= 0.0736, accuray(batch)= 100.00
# epoch= 7, loss(train)= 0.097, accuracy(train)= 99.130, time= 77.473, lr= 0.03675
#   accuracy(test) = 99.050 %, time= 6.354
# epoch= 8, i=  100, loss(batch)= 0.0975, accuray(batch)= 99.00
# epoch= 8, i=  200, loss(batch)= 0.0716, accuray(batch)= 100.00
# epoch= 8, i=  300, loss(batch)= 0.0747, accuray(batch)= 100.00
# epoch= 8, i=  400, loss(batch)= 0.0683, accuray(batch)= 100.00
# epoch= 8, i=  500, loss(batch)= 0.0771, accuray(batch)= 100.00
# epoch= 8, i=  600, loss(batch)= 0.0794, accuray(batch)= 99.00
# epoch= 8, loss(train)= 0.090, accuracy(train)= 99.188, time= 77.468, lr= 0.03492
#   accuracy(test) = 99.050 %, time= 6.614
# epoch= 9, i=  100, loss(batch)= 0.0710, accuray(batch)= 100.00
# epoch= 9, i=  200, loss(batch)= 0.0891, accuray(batch)= 99.00
# epoch= 9, i=  300, loss(batch)= 0.0655, accuray(batch)= 100.00
# epoch= 9, i=  400, loss(batch)= 0.0875, accuray(batch)= 98.00
# epoch= 9, i=  500, loss(batch)= 0.0927, accuray(batch)= 99.00
# epoch= 9, i=  600, loss(batch)= 0.0870, accuray(batch)= 99.00
# epoch= 9, loss(train)= 0.086, accuracy(train)= 99.253, time= 80.116, lr= 0.03317
#   accuracy(test) = 99.140 %, time= 6.527
# epoch= 10, i=  100, loss(batch)= 0.0678, accuray(batch)= 100.00
# epoch= 10, i=  200, loss(batch)= 0.0720, accuray(batch)= 99.00
# epoch= 10, i=  300, loss(batch)= 0.0760, accuray(batch)= 99.00
# epoch= 10, i=  400, loss(batch)= 0.1378, accuray(batch)= 98.00
# epoch= 10, i=  500, loss(batch)= 0.0719, accuray(batch)= 100.00
# epoch= 10, i=  600, loss(batch)= 0.0631, accuray(batch)= 100.00
# epoch= 10, loss(train)= 0.079, accuracy(train)= 99.383, time= 77.424, lr= 0.03151
#   accuracy(test) = 98.900 %, time= 6.233
# epoch= 11, i=  100, loss(batch)= 0.0736, accuray(batch)= 99.00
# epoch= 11, i=  200, loss(batch)= 0.0622, accuray(batch)= 100.00
# epoch= 11, i=  300, loss(batch)= 0.0611, accuray(batch)= 100.00
# epoch= 11, i=  400, loss(batch)= 0.0626, accuray(batch)= 100.00
# epoch= 11, i=  500, loss(batch)= 0.0931, accuray(batch)= 99.00
# epoch= 11, i=  600, loss(batch)= 0.0576, accuray(batch)= 100.00
# epoch= 11, loss(train)= 0.076, accuracy(train)= 99.392, time= 77.381, lr= 0.02994
#   accuracy(test) = 98.770 %, time= 6.314
# epoch= 12, i=  100, loss(batch)= 0.0608, accuray(batch)= 100.00
# epoch= 12, i=  200, loss(batch)= 0.0624, accuray(batch)= 100.00
# epoch= 12, i=  300, loss(batch)= 0.0644, accuray(batch)= 100.00
# epoch= 12, i=  400, loss(batch)= 0.0962, accuray(batch)= 99.00
# epoch= 12, i=  500, loss(batch)= 0.0873, accuray(batch)= 98.00
# epoch= 12, i=  600, loss(batch)= 0.0981, accuray(batch)= 98.00
# epoch= 12, loss(train)= 0.072, accuracy(train)= 99.438, time= 77.348, lr= 0.02844
#   accuracy(test) = 98.960 %, time= 6.362
# epoch= 13, i=  100, loss(batch)= 0.0645, accuray(batch)= 100.00
# epoch= 13, i=  200, loss(batch)= 0.0611, accuray(batch)= 100.00
# epoch= 13, i=  300, loss(batch)= 0.0578, accuray(batch)= 100.00
# epoch= 13, i=  400, loss(batch)= 0.0600, accuray(batch)= 100.00
# epoch= 13, i=  500, loss(batch)= 0.0738, accuray(batch)= 99.00
# epoch= 13, i=  600, loss(batch)= 0.0873, accuray(batch)= 97.00
# epoch= 13, loss(train)= 0.070, accuracy(train)= 99.433, time= 77.288, lr= 0.02702
#   accuracy(test) = 98.970 %, time= 6.287
# epoch= 14, i=  100, loss(batch)= 0.0915, accuray(batch)= 99.00
# epoch= 14, i=  200, loss(batch)= 0.0621, accuray(batch)= 99.00
# epoch= 14, i=  300, loss(batch)= 0.0833, accuray(batch)= 99.00
# epoch= 14, i=  400, loss(batch)= 0.0598, accuray(batch)= 100.00
# epoch= 14, i=  500, loss(batch)= 0.0540, accuray(batch)= 100.00
# epoch= 14, i=  600, loss(batch)= 0.1006, accuray(batch)= 97.00
# epoch= 14, loss(train)= 0.068, accuracy(train)= 99.450, time= 77.341, lr= 0.02567
#   accuracy(test) = 99.200 %, time= 6.258
# epoch= 15, i=  100, loss(batch)= 0.1619, accuray(batch)= 97.00
# epoch= 15, i=  200, loss(batch)= 0.0647, accuray(batch)= 99.00
# epoch= 15, i=  300, loss(batch)= 0.0630, accuray(batch)= 100.00
# epoch= 15, i=  400, loss(batch)= 0.1084, accuray(batch)= 98.00
# epoch= 15, i=  500, loss(batch)= 0.0560, accuray(batch)= 100.00
# epoch= 15, i=  600, loss(batch)= 0.0523, accuray(batch)= 100.00
# epoch= 15, loss(train)= 0.065, accuracy(train)= 99.540, time= 77.650, lr= 0.02438
#   accuracy(test) = 99.160 %, time= 6.268
# epoch= 16, i=  100, loss(batch)= 0.0556, accuray(batch)= 100.00
# epoch= 16, i=  200, loss(batch)= 0.0590, accuray(batch)= 100.00
# epoch= 16, i=  300, loss(batch)= 0.0867, accuray(batch)= 98.00
# epoch= 16, i=  400, loss(batch)= 0.0659, accuray(batch)= 100.00
# epoch= 16, i=  500, loss(batch)= 0.0610, accuray(batch)= 99.00
# epoch= 16, i=  600, loss(batch)= 0.0654, accuray(batch)= 99.00
# epoch= 16, loss(train)= 0.064, accuracy(train)= 99.530, time= 77.338, lr= 0.02316
#   accuracy(test) = 99.110 %, time= 6.501
# epoch= 17, i=  100, loss(batch)= 0.0531, accuray(batch)= 100.00
# epoch= 17, i=  200, loss(batch)= 0.0708, accuray(batch)= 99.00
# epoch= 17, i=  300, loss(batch)= 0.0658, accuray(batch)= 99.00
# epoch= 17, i=  400, loss(batch)= 0.0700, accuray(batch)= 99.00
# epoch= 17, i=  500, loss(batch)= 0.0482, accuray(batch)= 100.00
# epoch= 17, i=  600, loss(batch)= 0.0509, accuray(batch)= 100.00
# epoch= 17, loss(train)= 0.061, accuracy(train)= 99.562, time= 77.303, lr= 0.02201
#   accuracy(test) = 99.090 %, time= 6.378
# epoch= 18, i=  100, loss(batch)= 0.0720, accuray(batch)= 98.00
# epoch= 18, i=  200, loss(batch)= 0.0561, accuray(batch)= 100.00
# epoch= 18, i=  300, loss(batch)= 0.0732, accuray(batch)= 99.00
# epoch= 18, i=  400, loss(batch)= 0.0612, accuray(batch)= 100.00
# epoch= 18, i=  500, loss(batch)= 0.0559, accuray(batch)= 100.00
# epoch= 18, i=  600, loss(batch)= 0.0540, accuray(batch)= 100.00
# epoch= 18, loss(train)= 0.060, accuracy(train)= 99.605, time= 77.495, lr= 0.02091
#   accuracy(test) = 99.240 %, time= 6.261
# epoch= 19, i=  100, loss(batch)= 0.0686, accuray(batch)= 98.00
# epoch= 19, i=  200, loss(batch)= 0.0520, accuray(batch)= 100.00
# epoch= 19, i=  300, loss(batch)= 0.0712, accuray(batch)= 99.00
# epoch= 19, i=  400, loss(batch)= 0.0548, accuray(batch)= 99.00
# epoch= 19, i=  500, loss(batch)= 0.0512, accuray(batch)= 100.00
# epoch= 19, i=  600, loss(batch)= 0.0566, accuray(batch)= 100.00
# epoch= 19, loss(train)= 0.058, accuracy(train)= 99.627, time= 77.577, lr= 0.01986
#   accuracy(test) = 99.130 %, time= 6.421
# epoch= 20, i=  100, loss(batch)= 0.0572, accuray(batch)= 100.00
# epoch= 20, i=  200, loss(batch)= 0.0597, accuray(batch)= 99.00
# epoch= 20, i=  300, loss(batch)= 0.0638, accuray(batch)= 99.00
# epoch= 20, i=  400, loss(batch)= 0.0475, accuray(batch)= 100.00
# epoch= 20, i=  500, loss(batch)= 0.0490, accuray(batch)= 100.00
# epoch= 20, i=  600, loss(batch)= 0.0465, accuray(batch)= 100.00
# epoch= 20, loss(train)= 0.056, accuracy(train)= 99.672, time= 77.549, lr= 0.01887
#   accuracy(test) = 99.110 %, time= 6.195

# %%
import os
# Out:
# /home/yuhao/Projects/CE7454_Project_Group_5

# %% [markdown]
# ### Model 1- A neural algorithm of artistic style
#
# Refer to details in the following notebook:
# #####                           end2end_and_artistic_style_transfer/neural_artistic_style/neural_style_transfer.ipynb

# %%
os.chdir('end2end_and_artistic_style_transfer/neural_artistic_style/')

# %run neural_style_transfer.ipynb

os.chdir(cur_dir)
# Out:
# 1 / 13
# 2 / 13
# 3 / 13
# 4 / 13
# 5 / 13
# 6 / 13
# 7 / 13
# 8 / 13
# 9 / 13
# 10 / 13
# 11 / 13
# 12 / 13
# 13 / 13
# saved all images  >>  ../../outputs/neural_style_transfer/2018-Nov-15_03-19/

# %% [markdown]
# ### Model 2- End-to-end neural style transfer
#
# Refer to details in the following notebook: (for training)
# #####                           end2end_and_artistic_style_transfer/end2end_neural_style_transfer/pytorch-CycleGAN-and-pix2pixipynb

# %%
os.chdir('end2end_and_artistic_style_transfer/end2end_neural_style_transfer/')

# %run stylize.py  ../../trained_models/end2end_cnt1_2.pth ../../data/testA/ ../../outputs/end2end_neural_transfer/   

os.chdir(cur_dir)
# Out:
# {'--help': 0,
#  '--resize': 'None',
#  '.pth': False,
#  'Arguments:': False,
#  'INPUT': ['../../data/testA/'],
#  'Load': False,
#  'MODEL': ['../../trained_models/end2end_cnt1_2.pth'],
#  'None': False,
#  'OUTPUT': '../../outputs/end2end_neural_transfer/',
#  'OUTPUT.': None,
#  'Options:': False,
#  'Pytorch': False,
#  'Resize': False,
#  'Show': False,
#  'and': False,
#  'default:': False,
#  'dict': False,
#  'edge': False,
#  'file': 0,
#  'image': False,
#  'input': 0,
#  'into': False,
#  'it': False,
#  'of': False,
#  'output': False,
#  'path': False,
#  'screen': False,
#  'shorter': False,
#  'state': False,
#  'the': False,
#  'this': False,
#  'to': False,
#  'transform': False,
#  'use': False}
# GPU available >> device id:  1
# created dataset with dir >>  ../../data/testA/
# loading model from  path <<  ../../trained_models/end2end_cnt1_2.pth
# start file transformation...saving into path >> ../../outputs/end2end_neural_transfer/2018-Nov-15_03-26/
# 0  /  13
# 10  /  13
# saved to >>  ../../outputs/end2end_neural_transfer/2018-Nov-15_03-26/

# %% [markdown]
# ### Model 3 - CycleGAN
#
# Refer to details in the following file:
# #####           pytorch-CycleGAN-and-pix2pix/models/cycle_gan_model.py

# %%
os.chdir('pytorch-CycleGAN-and-pix2pix/')

# %run test.py --dataroot ../data/ --name celeba2comic_origin  --model cycle_gan  --direction AtoB --results_dir ../outputs/cycleGAN

print('end...saved to >> ../outputs/cycleGAN/')
os.chdir(cur_dir)
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                  dataroot: ../data/                      	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                  fineSize: 256
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                  loadSize: 256
#          max_dataset_size: inf
#                     model: cycle_gan                     	[default: test]
#                n_layers_D: 3
#                      name: celeba2comic_origin           	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: resnet_9blocks
#                       ngf: 64
#                no_dropout: True
#                   no_flip: False
#                      norm: instance
#                     ntest: inf
#                  num_test: 50
#               num_threads: 4
#                 output_nc: 3
#                     phase: test
#            resize_or_crop: resize_and_crop
#               results_dir: ../outputs/cycleGAN           	[default: ./results/]
#            serial_batches: False
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
# dataset [UnalignedDataset] was created
# initialize network with normal
# initialize network with normal
# model [CycleGANModel] was created
# loading the model from ./checkpoints/celeba2comic_origin/latest_net_G_A.pth
# loading the model from ./checkpoints/celeba2comic_origin/latest_net_G_B.pth
# ---------- Networks initialized -------------
# [Network G_A] Total number of parameters : 11.378 M
# [Network G_B] Total number of parameters : 11.378 M
# -----------------------------------------------
# processing (0000)-th image... ['../data/testA/000006.jpg']
# processing (0005)-th image... ['../data/testA/000155.jpg']
# processing (0010)-th image... ['../data/testA/000876.jpg']
